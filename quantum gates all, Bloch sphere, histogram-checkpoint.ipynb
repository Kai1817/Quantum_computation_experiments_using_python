# %%
from qiskit import*

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.measure_all()
# %matplotlib inline 
qc.draw(output='mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(out)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc, backend=simulator).result()
from qiskit.visualization import plot_histogram
plot_histogram(result.get_counts(qc))

# %%
pc = QuantumCircuit(1)
pc.y(0)
pc.measure_all()
# %matplotlib inline 
pc.draw(output='mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(pc,backend).result().get_statevector()
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(out)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(pc, backend=simulator).result()
from qiskit.visualization import plot_histogram
plot_histogram(result.get_counts(pc))

# %%
hc = QuantumCircuit(1)
hc.z(0)
hc.measure_all()
# %matplotlib inline 
hc.draw(output='mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(hc,backend).result().get_statevector()
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(out)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(hc, backend=simulator).result()
from qiskit.visualization import plot_histogram
plot_histogram(result.get_counts(hc))

# %%
circuit = QuantumCircuit(1)
circuit.h(0)
circuit.measure_all()
# %matplotlib inline 
circuit.draw(output='mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(circuit,backend).result().get_statevector()
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(out)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=simulator).result()
from qiskit.visualization import plot_histogram
plot_histogram(result.get_counts(circuit))

# %%
from math import pi

# %%
cir = QuantumCircuit(1)
cir.rz(pi, 0)
cir.measure_all()
# %matplotlib inline 
cir.draw(output='mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(cir,backend).result().get_statevector()
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(out)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(cir, backend=simulator).result()
from qiskit.visualization import plot_histogram
plot_histogram(result.get_counts(cir))

# %%
circ = QuantumCircuit(1)
circ.rz(pi/2, 0)
circ.measure_all()
# %matplotlib inline 
circ.draw(output='mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(circ,backend).result().get_statevector()
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(out)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circ, backend=simulator).result()
from qiskit.visualization import plot_histogram
plot_histogram(result.get_counts(circ))

# %%
ckt = QuantumCircuit(1)
ckt.rz(pi/4, 0)
ckt.measure_all()
# %matplotlib inline 
ckt.draw(output='mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(ckt,backend).result().get_statevector()
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(out)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(ckt, backend=simulator).result()
from qiskit.visualization import plot_histogram
plot_histogram(result.get_counts(ckt))

# %%
qr = QuantumCircuit(2)
qr.cx(0,1)
qr.measure_all()
# %matplotlib inline 
qr.draw(output='mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(qr,backend).result().get_statevector()
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(out)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(qr, backend=simulator).result()
from qiskit.visualization import plot_histogram
plot_histogram(result.get_counts(qr))
